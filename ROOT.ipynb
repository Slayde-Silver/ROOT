# %% [markdown]
# <a href="https://colab.research.google.com/github/Slayde-Silver/ROOT/blob/main/ROOT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ROOT

# %%
from google.colab import drive
drive.mount('/ROOT')
# Out:
# Mounted at /ROOT

# %% [markdown]
# ## Inbox

# %% [markdown]
# ## Windows

# %% [markdown]
# ## MacOSX

# %% [markdown]
# ## Linux

# %% [markdown]
# ## UNIX

# %% [markdown]
# ## DOSBOX

# %% [markdown]
# ## Android

# %% [markdown]
# ## IOS

# %% [markdown]
# ## ISO

# %% [markdown]
# ## Cloud

# %% [markdown]
# ## Firmware

# %% [markdown]
# ## Network

# %% [markdown]
# ## Space

# %% [markdown]
# ## Time

# %% [markdown]
# ## Dev

# %% [markdown]
# ## UAT

# %% [markdown]
# ## PROD

# %% [markdown]
# ## ARCHIVE

# %% [markdown]
# ## DEL

# %% [markdown]
# ## Outbout
