# %% [markdown]
# <a href="https://colab.research.google.com/github/Slayde-Silver/ROOT/blob/main/ROOT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ROOT

# %%
from python3 import ROOT
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-2181710492.py in <cell line: 0>()
# ----> 1 from python3 import ROOT
#
# ModuleNotFoundError: No module named 'python3'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# ## Inbox

# %% [markdown]
# ## Windows

# %% [markdown]
# ## MacOSX

# %% [markdown]
# ## Linux

# %% [markdown]
# ## UNIX

# %% [markdown]
# ## DOSBOX

# %% [markdown]
# ## Android

# %% [markdown]
# ## IOS

# %% [markdown]
# ## ISO

# %% [markdown]
# ## Cloud

# %% [markdown]
# ## Firmware

# %% [markdown]
# ## Network

# %% [markdown]
# ## Space

# %% [markdown]
# ## Time

# %% [markdown]
# ## Dev

# %% [markdown]
# ## UAT

# %% [markdown]
# ## PROD

# %% [markdown]
# ## ARCHIVE

# %% [markdown]
# ## DEL

# %% [markdown]
# ## Outbout

# %% [markdown]
# # Task
# Create a script to monitor a Google Drive folder for new files and send a notification and update an inbox when a new file is detected.

# %% [markdown]
# ## Mount google drive
#
# ### Subtask:
# Mount Google Drive to access the files in your inbox folder.

# %% [markdown]
# **Reasoning**:
# Mount Google Drive to access the files in the inbox folder.
